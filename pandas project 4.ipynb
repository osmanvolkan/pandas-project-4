# %%
import pandas as pd

# %%
data=pd.read_csv("titanic.csv")

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # 2. Check the Last 3 Rows of The Dataset

# %%
data.tail(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %% [markdown]
# # 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
data.shape
# Out:
# (891, 15)

# %%
print("number of rows:" ,data.shape[0])
print("number of columns:" ,data.shape[1])
# Out:
# number of rows: 891
# number of columns: 15

# %% [markdown]
# # 4. Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# # 5. Get Overall Statistics About The Dataframe

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.describe(include="all")
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %% [markdown]
# # 6. Data Filtering

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
data[["age","sex"]]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
data["sex"]=="male"
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: sex, Length: 891, dtype: bool

# %%
sum(data["sex"]=="male")
# Out:
# 577

# %%
data[data["sex"]=="male"].head(5)
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  male  22.0      1      0   7.2500        S  Third    man
# 4         0       3  male  35.0      0      0   8.0500        S  Third    man
# 5         0       3  male   NaN      0      0   8.4583        Q  Third    man
# 6         0       1  male  54.0      0      0  51.8625        S  First    man
# 7         0       3  male   2.0      3      1  21.0750        S  Third  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 4        True  NaN  Southampton    no   True
# 5        True  NaN   Queenstown    no   True
# 6        True    E  Southampton    no   True
# 7       False  NaN  Southampton    no  False

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data['survived']==1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: survived, Length: 891, dtype: bool

# %%
data[data['survived']==1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # 7.Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
per_missing= data.isnull().sum() *100/ len(data)
per_missing
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# # 8. Drop the Cabin Column

# %%
data.drop("deck",axis=1,inplace=True)

# %%
data.drop("embark_town",axis=1,inplace=True)

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male alive  alone
# ...

# %% [markdown]
# # 9. Handle Missing Values

# %%
data["embarked"].mode() #we did this to see the most occuring value. This section is not numerical so we cant use average
# Out:
# 0    S
# dtype: object

# %%
data["embarked"].fillna("S",inplace=True)

# %%
data["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
data["age"].mean()
# Out:
# 29.69911764705882

# %%
data["age"].fillna(data["age"].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      0
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# # 10. Categorical Data Encoding

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male alive  alone
# 0    man        True    no  False
# 1  woman       False   yes  False
# 2  woman       False   yes   True
# 3  woman       False   yes  False
# 4    man        True    no   True

# %%
data["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
data["gender"]=data["sex"].map({"male":1,"female":0})

# %%
data
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male alive  alone  gender
# ...

# %%
x=data["sex"].map({"male":1,"female":0})
x
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    1
# 890    1
# Name: sex, Length: 891, dtype: int64

# %%
data.insert(3,"gender_new",x)

# %%
data
# Out:
#      survived  pclass     sex  gender_new        age  sibsp  parch     fare  \
# 0           0       3    male           1  22.000000      1      0   7.2500
# 1           1       1  female           0  38.000000      1      0  71.2833
# 2           1       3  female           0  26.000000      0      0   7.9250
# 3           1       1  female           0  35.000000      1      0  53.1000
# 4           0       3    male           1  35.000000      0      0   8.0500
# ..        ...     ...     ...         ...        ...    ...    ...      ...
# 886         0       2    male           1  27.000000      0      0  13.0000
# 887         1       1  female           0  19.000000      0      0  30.0000
# 888         0       3  female           0  29.699118      1      2  23.4500
# 889         1       1    male           1  26.000000      0      0  30.0000
# 890         0       3    male           1  32.000000      0      0   7.7500
#
# ...

# %%
data.head(1)
# Out:
#    survived  pclass   sex  gender_new   age  sibsp  parch  fare embarked  \
# 0         0       3  male           1  22.0      1      0  7.25        S
#
#    class  who  adult_male alive  alone  gender
# 0  Third  man        True    no  False       1

# %%
data["embarked"].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
pd.get_dummies(data,columns=["embarked"])
# Out:
#      survived  pclass     sex  gender_new        age  sibsp  parch     fare  \
# 0           0       3    male           1  22.000000      1      0   7.2500
# 1           1       1  female           0  38.000000      1      0  71.2833
# 2           1       3  female           0  26.000000      0      0   7.9250
# 3           1       1  female           0  35.000000      1      0  53.1000
# 4           0       3    male           1  35.000000      0      0   8.0500
# ..        ...     ...     ...         ...        ...    ...    ...      ...
# 886         0       2    male           1  27.000000      0      0  13.0000
# 887         1       1  female           0  19.000000      0      0  30.0000
# 888         0       3  female           0  29.699118      1      2  23.4500
# 889         1       1    male           1  26.000000      0      0  30.0000
# 890         0       3    male           1  32.000000      0      0   7.7500
#
# ...

# %%
data1=pd.get_dummies(data,columns=["embarked"],drop_first=True)

# %%
data1
# Out:
#      survived  pclass     sex  gender_new        age  sibsp  parch     fare  \
# 0           0       3    male           1  22.000000      1      0   7.2500
# 1           1       1  female           0  38.000000      1      0  71.2833
# 2           1       3  female           0  26.000000      0      0   7.9250
# 3           1       1  female           0  35.000000      1      0  53.1000
# 4           0       3    male           1  35.000000      0      0   8.0500
# ..        ...     ...     ...         ...        ...    ...    ...      ...
# 886         0       2    male           1  27.000000      0      0  13.0000
# 887         1       1  female           0  19.000000      0      0  30.0000
# 888         0       3  female           0  29.699118      1      2  23.4500
# 889         1       1    male           1  26.000000      0      0  30.0000
# 890         0       3    male           1  32.000000      0      0   7.7500
#
# ...

# %% [markdown]
# # 11. What is Univariate Analysis?
# How Many People Survived And How Many Died? How Many Passengers Were In First Class, Second Class, and Third Class? Number of Male And Female Passengers

# %%
#it is using one variable at a time while making analysis

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'gender_new', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'alive', 'alone',
#        'gender'],
#       dtype='object')

# %%
data["survived"].value_counts() #we see that this column contains categorical data
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
sns.countplot(data["survived"]) #therefore, we can use this command to visualize
# Out:
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
data["pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
sns.countplot(data["pclass"])
# Out:
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'gender_new', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'alive', 'alone',
#        'gender'],
#       dtype='object')

# %%
data['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
sns.countplot(data['sex'])
# Out:
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.hist(data["age"]) #here we have numerical value, so the code we use has changed.
# Out:
# (array([ 54.,  46., 177., 346., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(data["age"])
# Out:
# d:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# # 12. Bivariate Analysis
# Who Has Better Chance of Survival Male or Female?
# Which Passenger Class Has Better Chance of Survival (First, Second, Or Third Class)?

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'gender_new', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'alive', 'alone',
#        'gender'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'gender_new', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'alive', 'alone',
#        'gender'],
#       dtype='object')

# %%
#who Has Better Chance of Survival Male or Female. our dependent variable is survived column,other columns are indepentdent variables.

# %%
sns.barplot(x="sex",y="survived",data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='pclass',y="survived",data=data)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='survived'>

# %% [markdown]
# # 13. Feature Engineering

# %%
#it is the process of extracting domain knowledge to extract features from raw data, using data mining techniques

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'gender_new', 'age', 'sibsp', 'parch',
#        'fare', 'embarked', 'class', 'who', 'adult_male', 'alive', 'alone',
#        'gender'],
#       dtype='object')

# %%
'sibsp' 'parch'
# Out:
# 'sibspparch'

# %%
data["Family_Size"]=data['parch']+data['sibsp']

# %%
data.head(1)
# Out:
#    survived  pclass   sex  gender_new   age  sibsp  parch  fare embarked  \
# 0         0       3  male           1  22.0      1      0  7.25        S
#
#    class  who  adult_male alive  alone  gender  Family_Size
# 0  Third  man        True    no  False       1            1

# %%
data["fare_per_person"]=data['fare'] / (data["Family_Size"] + 1)

# %%
data.head(1)
# Out:
#    survived  pclass   sex  gender_new   age  sibsp  parch  fare embarked  \
# 0         0       3  male           1  22.0      1      0  7.25        S
#
#    class  who  adult_male alive  alone  gender  Family_Size  fare_per_person
# 0  Third  man        True    no  False       1            1            3.625
